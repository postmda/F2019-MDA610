# %% [markdown]
# # Python 3 A Short Tutorial

# %% [markdown]
# # 1. Using the Python Interpreter
#
# ### IPython User Interfaces
# -  IPython Shell: type "ipython" on the command line
# -  IPython Console: Spyder
# -  Jupyter Notebook
#
# ### Magic Commands
# -  Shell commands with %: %pwd, %ls, %cd
# -  Magic commands
#     - %run
#     - %matplotlib inline
#
# ### Help and Documentation
# -  Displaying a docstring with help() function
# -  Introspection with ?
# -  Accessing source code with ??
# -  Tab completion

# %%
# Initializaiton
import sys
# %load_ext autoreload
# %autoreload 2
sys.setrecursionlimit(1500)

# %%
# magic command: running external code
# %run -t fib

# %%
# import a module
import fib

# %%
#  help and documentation
help(fib.fib)

# %%
# introspection
fib.fib?

# %%
# accesing the source code
fib.fib??

# %%
# call gcdr()
# %run -t gcd

# %%
# %run -p gcd

# %%
# call grd()
# %run -t gcd

# %%
# %run -p gcd

# %% [markdown]
# # 2. Basics

# %% [markdown]
# ## Typing Python
# -  Comments: #
# -  Several statements on the same line: separated by semicolons
# -  Continuation symbol: \
# -  Indentation, not braces
#
# ```Python
# a, b = 0, 1
# for i in range(10):
#     a, b = b, a + b
# return a
# ```

# %%
a = 4; b = 5.5; c = 9.0
d = 6.0 * a - b ** 2 + \
   c ** (a + b)
# no continuation symbol is needed
e = 6.0 * a - b **2 + c ** (
   a + b)

# %% [markdown]
# ## Objects and Identifiers
# -  An object is a region of computer memory containg both data and information (type and identity) associated with the data.
# -  An identifier is a label attached to an object.
# -  Identifiers are case sensitive.

# %%
# <identifier> = <object>
one = 1   # Assign 1 to variable one
two = 2 * one   # Assign twice of variable one to variable two

# %%
# find the type of an object
type(one)

# %%
# find the identity of an object
id(one)

# %%
# dynamic referencing
a = 1
print("a:", id(a))
print("1:", id(1))
a = a + 1
print("a:", id(a))
print("2:", id(2))
b = 1
print("b:", id(b))

# %% [markdown]
# ## Scalar Types
# -  None
# -  bytes
# -  float
# -  bool
# -  int

# %% [markdown]
# ### Integers
# -  arithematic operators: ```+ - * /```
# -  integer division ```//```
# -  exponentiation ```**```
# -  modulus ```%```
# -  assignment operators: ```+=  -=  *=  /=```

# %%
# division
7 / 5

# %%
# floor division
-7 // 5

# %%
# remainder
7 % 5

# %%
# Brackets take first priority; followed by exponentiation, then division
# or multiplication, and finally addition and subtraction.
(6 - 2) ** 2 / (12 - (8 - 3) / 2.5)

# %%
# assignment operators
x = 8
print(id(x))
x += 2
x
print(id(x))

# %% [markdown]
# ### Floats
# -  arithematic operators: ```+ - * /```
# -  exponentiation ```**```
# -  assignment operators: ``` +=  -=   *=  /= ```
# -  widening an int: ```float()```
# -  narrowing a float: ```int()``` truncation towards zero

# %%
# same float 
x = -3.14
y = -314e-2

# %%
# widening
float(4)

# %%
# narrowing
int(-3.5)

# %%
# built-in math functions
abs(-5.2)

# %%
# import the math module
import math
dir(math)

# %%
math.log(5.2)

# %%
math.pi

# %% [markdown]
# ### Boolean Numbers
# -  ```True``` and ```False```
# -  Comparison operators: ```<  >  == !=  <=  >=```
# -  Logic operators: ```and  or  not```

# %%
2 ** 3 == 8

# %%
x = 3
y = 2
x > 1 and y < 4

# %%
not x > 5

# %%
0 <= 1 > 0.5 < 0.8

# %% [markdown]
# ## Namespaces and Modules
# -  A **namesapce** is a list of identifiers that have been assigned to objects.
# -  A **module** is a file with extension .py that contains python definitions and statements.
# -  Importing a module makes the namespace of the module available.

# %%
# Import a module and create a reference to that module in the current namespace. You need to define 
# a complete path gcd.name or gcd.attribute when referring to an object in the module
import gcd
gcd.gcdr(5, 2)

# %%
# Import an object and create a reference to the object from the current namespace. 
# Use the identifer without the module name. 
from gcd import gcdr
gcdr(5, 2)

# %%
# a quick and dirty import, but not recommended
from gcd import *
gcd(5, 2)

# %%
# use an alias
import numpy as np
np.array?

# %% [markdown]
# ## Container Objects
# -  Lists
# -  Tuples
# -  Strings
# -  Dictionaries

# %% [markdown]
# ### Lists

# %%
# elements can be of different types
u = []  # an empty list
u = [1, 4.0, 'a']
u.append('foo')   # add an element to the end
print(u)

# %%
u.pop()   # remove the last element

# %%
# len() returns the number of elements
len(u)

# %%
# a nested list
v = [3, 5, 7]
u.append(v)
u

# %%
# replicate a list
u * 2

# %%
# appending or extending a list
alist = [1, 3, 5]
blist = [2, 4, 6]
alist.append(blist)
print(alist)
alist.extend(blist)
print(alist)

# %%
# insert an element to a list
clist = [1, 3, 5]
clist.insert(2, 4)
clist

# %%
# remove an element
dlist = [1, 2, 1, 3, 1]
dlist.remove(1)
dlist

# %% [markdown]
# ### List Indexing

# %%
# indexing starts with 0 and ends with len(u)-1
u = [10, 20, 30, 40, 50]
print(u[3])   # 40
# reverse order
print(u[-1])  # 50
print(u[-3])  # 30

# %%
# remove the item at the specified index
del u[2]
len(u)

# %%
# indexing a nested list
wlist = [1, 2, ['MDA 520', 'MDA 610', 'MDA 621'], 3]
wlist[2][1]

# %% [markdown]
# ### List Slicing
# - Slicing is to get a subset of the elements in a container object.
# - A slice is in the form of [start:end:step].
# - A slice of a list is a new object.

# %%
u = [0, 1, 2, 3, 4, 5, 6]
print(u[2:4])  # [2, 3]
v = u[2:4]
v[0] = 12
print(u)   # u remains the same
u[2:4] = [12, 13]
print(u)   # [0, 1, 12, 13, 4, 5, 6]
print(v)   # v remains the same

# %%
print(u[0:6])   # the last element is missing
print(u[:])   # all elements are displayed
print(u[::2])   # [0, 12, 4, 6]
print(u[::-1])  # all elements in reverse order

# %% [markdown]
# ### List Mutability
# -  Lists and dictionaries are mutable.
# -  Scalars, strings and tuples are immutable.

# %%
a = 4
b = a
b = 'foo'
print(a)   # immutable
print(b)

# %%
u = [0, 2, 4, 6]
v = u
v[2] = 5
print(u)   # mutable

# %%
u = [0, 2, 4, 6]
v = u.copy()   # deep copy
v[2] = 5
print(u)   # [0, 2, 4, 6]

# %% [markdown]
# ### Tuples
# -  () can be dropped.
# -  Tuples are immutable.
# -  Indexing and slicing work in the same way as for lists.

# %%
(a, b, c, d) = (4, 3.0, 'a', [1, 2, 3])
d[2]

# %%
# an alternative way to declare a tuple
g, h = 5, 6
g

# %%
# swap two objects
x = 3
y = 5
x, y = y, x
print(x, y)

# %%
# a tuple with one element
atup = (x, )
atup[0]

# %%
# tuple packing
btup = 'LIU', 'CoM', 'MDA'
# tuple unpacking
univ, school, program = btup
univ

# %% [markdown]
# ### Strings
#
# -  Single quotes '...'
# -  Double quotes "..."
# -  Triple-quotes '''...''' or """...""": a single string spans multiple lines
# -  Concatenation operator: ```+```
# -  Repetition operator: ```*```
# -  Strings are immutable containter objects.
# -  Indexing and slicing work in the same way as for lists.

# %%
'LIU'

# %%
'doesn\'t'   # use \' to escape the single quote

# %%
"doesn't"

# %%
'FirstLine\nSecondLine'    # \n means a new line; but without print(), \n is included in the output

# %%
print('FirstLine\nSecondLine')  # with print(), \n produces a new line

# %%
print('C:\some\name')   # \n means a new line

# %%
print(r'C:\some\name')  # r before the quote prevents the character prefaced by \ 
                        # from being interpreted as a special character
print('C:\\some\\name') # an alternative way

# %%
3*'abc'+'de'   # 3 times 'abc', followed by 'de'

# %%
print("Long Island University", "Post Campus")   # output multiple strings

# %%
# indexing
'LIU'[:2]

# %%
# accepting user inputs
name = input("What is your name?\t")
age = int(input("How old are you?\t")) 
print("Your name is {}. ".format(name) + "You are {} years old.".format(age))

# %% [markdown]
# ### Dictionaries
# -  A dictionary object is an unordered collection of key-object pairs.
# -  Items are fetched via keys rather than positions.

# %%
# an empty dictionary
adict = {}
# define a dictionary
bdict = {'a' : 1, 'b' : 2}
# add an item
bdict['c'] = 3
bdict

# %%
# is a key in the dictionary?
print('a' in bdict)
print('d' in bdict)

# %%
# a list of keys
bdict.keys()

# %%
del bdict['c']
bdict

# %% [markdown]
# ## ```if``` Statement
# ```Python
# if <Boolean expression1>:
#     <block1>
# elif <Boolean expression2>:
#     <block2>
# elif <Boolean expression3>:
#     <block3>
# else:
#     <block4>
# <block5>
# ```

# %%
x = 0.47
if 0 < x < 1:
    print('x lies between 0 and 1.')

# %%
x = 5.8
if x < 0: 
    print("x is negative.")
elif x == 0:
    print("x is zero.")
elif 0 < x < 5:
    print("x is positive but small than 5.")
else:
    print("x is positive and larger than or equal to 5.")

# %% [markdown]
# ## Loop Constructs

# %% [markdown]
# ### ```for``` Loop
#
# ```Python
# for <iterator> in <iterable>:
#     <block>
# ```
# -  `<iterable>` is any container object.
# -  `<iterator>` can be used to access the elements of the container object.

# %%
# a string
for c in "Python":
    print(c, end = " ")

# %%
# enumerate() returns an enumerate object -- a list of tuples in the form of (index, list_element).
alist = [1, 2, 3, 4, 5]
for index, obj in enumerate(alist):
    print(index, obj)

# %%
# dict.items() returns a list of tuples in the form of (key, object).
adict = {'one': 1, 'two': 2, 'three': 3}
for index, (key, obj) in enumerate(adict.items()):
    print(index, key, obj)

# %%
# range() generates a sequence of numbers.
for i in range(3, 11, 2):
    print(i)

# %%
# access a list 
alist = [11, 12, 13, 14, 15]
for i in range(len(alist)):
    print(alist[i], end = " ")

# %% [markdown]
# ### ```countinue``` Statement
# ```Python
# for <iterator> in <iterable>:
#     <block1>
#     if <test1>:
#         continue
#     <block2>
# <block3>
# ```
# -  If &lt;test1&gt; returns ```True```, the next pass commences.

# %% [markdown]
# ### ```break``` Statement
# ```Python
# for <iterator> in <iterable>:
#     <block1>
#     if <test2>:
#         break
#     <block2>
# else:
#     <block3>
# <block4>
# ```
# -  If &lt;test2&gt; returns ```True```, the loop terminates.
# -  The ```else``` clause is executed when the loop terminates unless it is terminated by a ```break``` statement.

# %%
# is the input a prime or a composite?
y = int(input("input an integer: "))
for x in range(y):
    if x < 2:
        continue;
    if y % x == 0:
        print(y, "is composite.")
        break
else:
    print(y, "is prime.")

# %% [markdown]
# ### List Comprehensions
# - A list comprehension uses a list to construct a second list.

# %%
# a list of squares
squares = [x ** 2 for x in range(10)]
squares

# %%
# a list of squares for the odd numbers
squares = [x ** 2 for x in range(10) if x % 2]
squares

# %% [markdown]
# ### ```while``` Loop
# ```Python
# while <test>:
#     <block1>
# <block2>
# ```
# -   ```else```, ```continue```, and ```break``` clauses are available.

# %%
# be careful of an infinite loop
i = 1
sum = 0
while i <= 10:
    sum += i
    i += 1
print(sum)

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Syntax and Scope
# ```Python
# def <name>(<arglist>):
#     <body>
# ```
# -  The ```return``` statement returns an object or multiple objects.
# -  A function can access variables in the *global* namespace and the *local* namespace.
# -  The local namespace is destroyed when the function is finished.

# %%
# define a function that returns a tuple
def add_x_and_y(x, y):
    """ add x and y and return them and their sum """
    z = x + y
    return x, y, z

# %%
a, b, c = add_x_and_y(3.5, 4.0)
print(a, b, c)

# %%
# mutatable arguments
L = [1, 2, 3]
def add_with_side_effect(M):
    M[0] += 1

add_with_side_effect(L)
L

# %%
# apply slicing
L = [1, 2, 3]
def add_without_side_effect(M):
    MC = M[:]
    MC[0] += 1
    return MC

L = add_without_side_effect(L)
L

# %% [markdown]
# ### Positional Arguments

# %%
# define a function with three parameters
def foo1(a, b, c):
    return a + b + c

# %%
# pass arguments as positional argument
foo1(1, 2, 3)

# %% [markdown]
# ### Keyword Arguments
# -  When a function is called, keyword arguments should follow positional arguments.

# %%
# pass arguments as keyword arguments
# order does not matter
foo1(c = 5, b = 4, a = 3)

# %%
# call a function with a mix of positional and keyword arguments
# keyword arguments should follow positional arguments
foo1(3, 5, c = 7)

# %% [markdown]
# ### Parameters with Default Values
# -  When a function is called, default arguments can be left out.
# -  When a function is defined, parameters with default values should follow parameters without default values.

# %%
def foo2(d, e = 5, f = 6):
    return d * e * f

# %%
# call function foo2()
# one to three arguments should be passed
print(foo2(4))
print(foo2(2, 8))
print(foo2(3, f = 10))
print(foo2(1, 2, 3))

# %% [markdown]
# ### Variable Number of Positional Arguments

# %%
# a tuple is used
def average(*args):
    """ Return mean of a non-empty tuple of numbers. """
    print(args)
    sum = 0.0
    for x in args:
        sum += x
    return sum / len(args)

print(average(1, 2, 3, 4))
print(average(1, 2, 3, 4, 5))
alist = [2, 4, 6]
print(average(*alist))   # *alist unpacks the list for a function call

# %% [markdown]
# ### Variable Number of Keyword Arguments

# %%
# a dictionary is used
def show(a, b, *args, **kwargs):
    print(a, b, args, kwargs)
    
show(1, 2, 5, 6, 7, alpha = 0.9, beta = 2.1)

# %% [markdown]
# ### Errors and Exception Handling

# %%
# the following function casts a string to a floating-point number
# an exception is raised if x could not be converted to a float
def attempt_float(x):
    try:
        return float(x)
    except:
        return(x)

# %%
attempt_float('123')

# %%
attempt_float('something')

# %%
attempt_float([123])

# %%
# catch the ValueError exception only
def attempt_float2(x):
    try:
        return float(x)
    except ValueError:
        return(x)

# %%
attempt_float2('something')

# %%
# TypeError
attempt_float2([123])

# %% [markdown]
# ### ```print``` Funciton
# -  A format placeholder: ```%[flags][width][.precision]type```
# -  String format method

# %%
# the old way to format output
print("%5d copies at a unit price of $%-7.2f" % (1000, 35.2))

# %%
# the Pythonic way
print("{0:5d} copies at a unit price of ${1:<7.2f}".format(1000, 35.2))

# %% [markdown]
# ### Anonymous Function

# %%
# lambda function is passed to the apply_to_list function as an object
def apply_to_list(some_list, f):
    return [f(x) for x in some_list]

apply_to_list([1, 2, 3, 4], lambda x : x * 2)

# %% [markdown]
# ### Map Function

# %%
# Map function returns a list of results after applying the given function to 
# each item of an iterable.
alist = [1, 2, 3, 4]
blist = list(map(lambda x: x ** 2, alist))
blist

# %% [markdown]
# ### Filter Function

# %%
# Filter function returns a list of items of an iterable that meets the condition given.
blist = list(filter(lambda x: x % 2 == 0, alist))
blist

# %% [markdown]
# ## Introduction to Python Classes
# -  Classes are the templates of your objects.
# -  Encapsulation: classes provide a means of bundling data and functionality together.
# -  An object is a class instance.
# -  Instance variable: Each instance has its own attributes.
# -  Class definition
# ```Python
# class ClassName:
#     <statements>
# ```
# -  The statements are usually function definitions.
# -  Class instantiation: ```x = MyClass(<arglist>)```
# -  Attribute references： ```obj.attr```
# -  Method references: ```x.f()```

# %%
# %run frac
